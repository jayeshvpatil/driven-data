# %% [markdown]
# DengAI: Predicting Disease Spread

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
pd.set_option('display.max_columns',None)

# Igore warning statements
import warnings
warnings.filterwarnings('ignore')

# %%
X = pd.read_csv('dengue_features_train.csv')
y = pd.read_csv('dengue_labels_train.csv')
df_test = pd.read_csv('dengue_features_test.csv')
holdout = df_test.copy()
df = pd.merge(X,y, left_on=['city','weekofyear','year'],right_on=['city','weekofyear','year'])

# %%
df.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.140531     0.119999     0.073860
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%    2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%    2005.000000    39.250000     0.248483     0.216600     0.248846
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1434.000000           1443.000000            1446.000000
# mean      0.202305             45.760388             298.701852
# std       0.083903             43.715537               1.362420
# min      -0.063457              0.000000             294.635714
# ...

# %%
#missing data
total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                                        Total   Percent
# ndvi_ne                                  194  0.133242
# ndvi_nw                                   52  0.035714
# station_diur_temp_rng_c                   43  0.029533
# station_avg_temp_c                        43  0.029533
# ndvi_se                                   22  0.015110
# ndvi_sw                                   22  0.015110
# station_precip_mm                         22  0.015110
# station_max_temp_c                        20  0.013736
# station_min_temp_c                        14  0.009615
# reanalysis_sat_precip_amt_mm              13  0.008929
# precipitation_amt_mm                      13  0.008929
# reanalysis_avg_temp_k                     10  0.006868
# reanalysis_air_temp_k                     10  0.006868
# reanalysis_max_air_temp_k                 10  0.006868
# reanalysis_dew_point_temp_k               10  0.006868
# reanalysis_min_air_temp_k                 10  0.006868
# ...

# %%
df.info()
df.drop(['week_start_date'],inplace=True,axis=1)
holdout.drop(['week_start_date'],inplace=True,axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1456 entries, 0 to 1455
# Data columns (total 25 columns):
# city                                     1456 non-null object
# year                                     1456 non-null int64
# weekofyear                               1456 non-null int64
# week_start_date                          1456 non-null object
# ndvi_ne                                  1262 non-null float64
# ndvi_nw                                  1404 non-null float64
# ndvi_se                                  1434 non-null float64
# ndvi_sw                                  1434 non-null float64
# precipitation_amt_mm                     1443 non-null float64
# reanalysis_air_temp_k                    1446 non-null float64
# reanalysis_avg_temp_k                    1446 non-null float64
# reanalysis_dew_point_temp_k              1446 non-null float64
# reanalysis_max_air_temp_k                1446 non-null float64
# ...

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train, y_test = train_test_split(df.iloc[:,0:-1],df['total_cases'], test_size=0.2, random_state=123)
X_train.shape
# Out:
# (1164, 23)

# %%
y_train.shape
# Out:
# (1164,)

# %%
from sklearn.preprocessing import Imputer
imputer = Imputer(missing_values='NaN',strategy='mean', axis=0)
imputer = imputer.fit(X_train.iloc[:,2:])
X_train.iloc[:,2:]= imputer.transform(X_train.iloc[:,2:])
imputer = imputer.fit(X_test.iloc[:,2:])
X_test.iloc[:,2:]= imputer.transform(X_test.iloc[:,2:])
imputer = imputer.fit(holdout.iloc[:,2:])
holdout.iloc[:,2:]= imputer.transform(holdout.iloc[:,2:])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

le.fit(X_train['city'])

X_train['city']  = le.transform(X_train['city'])
le.fit(X_test['city'])
X_test['city'] =le.transform(X_test['city'])
le.fit(holdout['city'])
holdout['city'] =le.transform(holdout['city'])
# Out:
#      city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0       1  2008        18.0 -0.018900 -0.018900  0.102729  0.091200
# 1       1  2008        19.0 -0.018000 -0.012400  0.082043  0.072314
# 2       1  2008        20.0 -0.001500  0.126803  0.151083  0.091529
# 3       1  2008        21.0  0.126050 -0.019867  0.124329  0.125686
# 4       1  2008        22.0  0.056800  0.039833  0.062267  0.075914
# 5       1  2008        23.0 -0.044000 -0.030467  0.132000  0.083529
# 6       1  2008        24.0 -0.044300 -0.024925  0.132271  0.159157
# 7       1  2008        25.0  0.126050  0.082150  0.144371  0.116729
# 8       1  2008        26.0  0.010800  0.049900  0.100571  0.117329
# 9       1  2008        27.0  0.072667  0.106660  0.155429  0.164900
# 10      1  2008        28.0 -0.046450  0.006825  0.260286  0.214729
# 11      1  2008        29.0  0.126050  0.126803  0.195843  0.176157
# 12      1  2008        30.0  0.208300  0.429500  0.277683  0.245650
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
y_holdout = lr.predict(holdout)

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(y_test,y_pred)
# Out:
# 18.246575342465754

# %%
from sklearn.ensemble import RandomForestClassifier

random_forest = RandomForestClassifier(n_estimators=300)
random_forest.fit(X_train, y_train)
Y_pred_winner = random_forest.predict(X_test)
mean_absolute_error(y_test,Y_pred_winner)
y_holdout = random_forest.predict(holdout)

# %%
output = pd.concat([df_test.iloc[:,0:3],pd.DataFrame(y_holdout, columns=['total_cases'])], axis=1)
output.to_csv('submission.csv',index=False)
