# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

df_train_values = pd.read_csv('training_set_values.csv')
df_train_labels = pd.read_csv('training_set_labels.csv')
df_test_values  = pd.read_csv('test_set_values.csv')

# %%
df_train_values.describe()
# Out:
#                  id     amount_tsh    gps_height     longitude      latitude  \
# count  59400.000000   59400.000000  59400.000000  59400.000000  5.940000e+04
# mean   37115.131768     317.650385    668.297239     34.077427 -5.706033e+00
# std    21453.128371    2997.574558    693.116350      6.567432  2.946019e+00
# min        0.000000       0.000000    -90.000000      0.000000 -1.164944e+01
# 25%    18519.750000       0.000000      0.000000     33.090347 -8.540621e+00
# 50%    37061.500000       0.000000    369.000000     34.908743 -5.021597e+00
# 75%    55656.500000      20.000000   1319.250000     37.178387 -3.326156e+00
# max    74247.000000  350000.000000   2770.000000     40.345193 -2.000000e-08
#
#         num_private   region_code  district_code    population  \
# count  59400.000000  59400.000000   59400.000000  59400.000000
# mean       0.474141     15.297003       5.629747    179.909983
# std       12.236230     17.587406       9.633649    471.482176
# ...

# %%
df_train_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
# id                       59400 non-null int64
# amount_tsh               59400 non-null float64
# date_recorded            59400 non-null object
# funder                   55765 non-null object
# gps_height               59400 non-null int64
# installer                55745 non-null object
# longitude                59400 non-null float64
# latitude                 59400 non-null float64
# wpt_name                 59400 non-null object
# num_private              59400 non-null int64
# basin                    59400 non-null object
# subvillage               59029 non-null object
# region                   59400 non-null object
# region_code              59400 non-null int64
# district_code            59400 non-null int64
# lga                      59400 non-null object
# ward                     59400 non-null object
# population               59400 non-null int64
# ...

# %%
df_final = pd.merge(df_train_values,df_train_labels,on='id')
df_final
# Out:
#           id  amount_tsh date_recorded                    funder  gps_height  \
# 0      69572      6000.0    2011-03-14                     Roman        1390
# 1       8776         0.0    2013-03-06                   Grumeti        1399
# 2      34310        25.0    2013-02-25              Lottery Club         686
# 3      67743         0.0    2013-01-28                    Unicef         263
# 4      19728         0.0    2011-07-13               Action In A           0
# 5       9944        20.0    2011-03-13       Mkinga Distric Coun           0
# 6      19816         0.0    2012-10-01                      Dwsp           0
# 7      54551         0.0    2012-10-09                     Rwssp           0
# 8      53934         0.0    2012-11-03                  Wateraid           0
# 9      46144         0.0    2011-08-03               Isingiro Ho           0
# 10     49056         0.0    2011-02-20                   Private          62
# ...

# %%
df_final.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private       ...        \
# 0  34.938093  -9.856322                  none            0       ...
# 1  34.698766  -2.147466              Zahanati            0       ...
# 2  37.460664  -3.821329           Kwa Mahundi            0       ...
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0       ...
# 4  31.130847  -1.825359               Shuleni            0       ...
#
#   water_quality quality_group      quantity  quantity_group  \
# ...

# %%
df_status_grp_cnt = df_final['status_group'].value_counts().to_frame()

df_totals = [status_group.sum()]

df_status_grp_cnt.reset_index(inplace=True)
df_status_grp_cnt.columns = ['Status Group','Value Counts']
df_status_grp_cnt.loc[:,'Total']= status_group.sum()
df_status_grp_cnt.loc[:,'%Total']= (df_status_grp_cnt['Value Counts']*100)/df_status_grp_cnt['Total']
df_status_grp_cnt.plot(kind='bar', x='Status Group', y='%Total')
plt.show()

# %%
grp_status = df_final.groupby('status_group')
functional_needs_rpr= df_final[df_final['status_group']=='functional needs repair']['quantity'].value_counts()
functional_qty = df_final[df_final['status_group']=='functional']['quantity'].value_counts()
non_functional_qty = df_final[df_final['status_group']=='non functional']['quantity'].value_counts()
df_status_qty = pd.DataFrame([functional_qty,non_functional_qty, functional_needs_rpr])
df_status_qty.index=['functional','non functional','functional needs repair']
df_status_qty.plot(kind='bar',stacked=True, figsize=(15,8))
plt.show()

# %%
pd.crosstab(df_final['status_group'],df_final['payment']).apply(lambda r: r/r.sum(),axis=1)
# Out:
# payment                  never pay     other  pay annually  pay monthly  \
# status_group
# functional                0.352739  0.018940      0.084938     0.169937
# functional needs repair   0.441742  0.027334      0.057216     0.214732
# non functional            0.528479  0.014239      0.028698     0.082851
#
# payment                  pay per bucket  pay when scheme fails   unknown
# status_group
# functional                     0.188785               0.075297  0.109365
# functional needs repair        0.094742               0.064165  0.100069
# non functional                 0.108920               0.052927  0.183885

# %%
df_final.hist()

# %%
NUMERIC_COLUMNS =['amount_tsh', 'gps_height','longitude','latitude','num_private','population','construction_year']

# %%
df_final.columns
# Out:
# Index(['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height',
#        'installer', 'longitude', 'latitude', 'wpt_name', 'num_private',
#        'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga',
#        'ward', 'population', 'public_meeting', 'recorded_by',
#        'scheme_management', 'scheme_name', 'permit', 'construction_year',
#        'extraction_type', 'extraction_type_group', 'extraction_type_class',
#        'management', 'management_group', 'payment', 'payment_type',
#        'water_quality', 'quality_group', 'quantity', 'quantity_group',
#        'source', 'source_type', 'source_class', 'waterpoint_type',
#        'waterpoint_type_group', 'status_group'],
#       dtype='object')

# %%
 set( df_final['quantity'].tolist() )
# Out:
# {'dry', 'enough', 'insufficient', 'seasonal', 'unknown'}

# %%
transformer_dict = {}
for ii, value in enumerate(set( df_final['quantity'].tolist() )):
    transformer_dict[value] = ii
transformer_dict
# Out:
# {'dry': 0, 'enough': 2, 'insufficient': 4, 'seasonal': 3, 'unknown': 1}
